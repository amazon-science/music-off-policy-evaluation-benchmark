# %% [markdown]
# # Benchmarking OPE on Amazon Music Data

# %% [markdown]
# This notebook performs _off-policy evaluation_ (OPE) using only the logged data. The policy (model) artifacts that generated the data are not needed for evaluation, as we have logged the selected actions from both the logging policy and target policy, for every context in the dataset. We also store the full propensity table (probability of ranking each item at each position) under the logging policy. The target policy is deterministic, so its propensities are not needed.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

np.random.seed(42)

# %%
from huggingface_hub import snapshot_download

# Download the parquet files once from the Hub and store them in local_dir.
# Re-running is a no-op once cached.

DATASET_DIR = snapshot_download(
  repo_id="amazon/music-off-policy-evaluation-benchmark",
  repo_type="dataset",
  local_dir="music-ope-dataset",
  allow_patterns=["D1/*.parquet", "D2/*.parquet"],
)
# Out:
# Fetching 169 files:   0%|          | 0/169 [00:00<?, ?it/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# ...

# %%
T1_DATASET_PATH = f"{DATASET_DIR}/D1"
T2_DATASET_PATH = f"{DATASET_DIR}/D2"

# Position Bias curve
PB = np.array(
    [
        1.0,
        0.76674848,
        0.33742719,
        0.26136553,
        0.20732642,
        0.16384161,
        0.13263467,
        0.11458964,
        0.11255035,
        0.09426026,
        0.07283572,
        0.07004059,
        0.06315475,
        0.05890552,
        0.05496263,
    ]
)

# %% [markdown]
# ### Ground Truth
#
# First, we compute the "ground truth" for T1 using the average of its logged rewards.

# %%
# %%time

from estimators.ground_truth import GroundTruth

result_ground_truth = GroundTruth(omega=1.018306600302338).evaluate(T1_DATASET_PATH)

# %%
print(result_ground_truth)

# %% [markdown]
# ### Reward Model
#
# We fit a **position-aware** XGBoost reward model (`binary:logistic`) on T1. It appends the 0-indexed display position to the 129-dim action context to represent position bias.

# %%
# %%time

from estimators.reward_model import PositionAwareXGBoostRewardModel

reward_model_xgb_pos = PositionAwareXGBoostRewardModel(
    n_estimators=500,
    max_depth=6,
    learning_rate=0.01,
    max_train_requests=None,
).fit(T1_DATASET_PATH)

reward_model_xgb_pos.model.set_params(n_jobs=1)

# %% [markdown]
# ### Estimates
#
# For each estimator, compute a reward estimate and confidence interval.

# %%
# %%time

from joblib import Parallel, delayed

from estimators.ipm import IPM
from estimators.pbm import PBM, PBMType
from estimators.interpol import INTERPOL
from estimators.sn_ipm import SelfNormalizedIPM
from estimators.dr import DoublyRobust
from estimators.dm import DirectMethod
from estimators.dr_shrinkage import DoublyRobustShrinkage
from estimators.dr_ranking import DoublyRobustRanking


estimators = [
    ("PBM-D", PBM(position_bias=PB, type=PBMType.DETERMINISTIC)),
    ("PBM-S", PBM(position_bias=PB, type=PBMType.STOCHASTIC)),
    ("IPM", IPM()),
    ("SN-IPM", SelfNormalizedIPM()),
    ("DM", DirectMethod(reward_model=reward_model_xgb_pos)),
    ("DR-IPM", DoublyRobust(reward_model=reward_model_xgb_pos)),
    ("DR-IPM-S", DoublyRobustShrinkage(
        reward_model=reward_model_xgb_pos, lambda_shrinkage=1.0)),
    ("DR-PBM", DoublyRobustRanking(
        reward_model=reward_model_xgb_pos, position_bias=PB, tau=1e-3)),
    ("Interpol(window=1)", INTERPOL(window_size=1, position_bias=PB)),
    ("Interpol(window=2)", INTERPOL(window_size=2, position_bias=PB)),
    ("Interpol(window=3)", INTERPOL(window_size=3, position_bias=PB)),
    ("Interpol(window=4)", INTERPOL(window_size=4, position_bias=PB)),
    ("Interpol(window=5)", INTERPOL(window_size=5, position_bias=PB)),
]

all_results = Parallel(n_jobs=15)(
    delayed(estimator.benchmark)(name, T2_DATASET_PATH, result_ground_truth)
    for (name, estimator) in estimators
)

rows = []
for name, results, err in all_results:
    rows.append(
        {
            "estimator": name,
            "metric": results.metric,
            "err_lower": results.metric - results.ci.lower_bound,
            "err_upper": results.ci.upper_bound - results.metric,
            "lower_bound": results.ci.lower_bound,
            "upper_bound": results.ci.upper_bound,
            "ground_truth": result_ground_truth.metric,
            "bias2": err.bias2,
            "var": err.var,
            "mse": err.mse,
        }
    )

# %% [markdown]
# ### Visualize Results

# %%
df = pd.DataFrame(rows).set_index("estimator")
df.to_csv("OPE.csv", index_label="estimator")

# %%
df

# %%
ax = df.plot.bar(
    y="metric",
    yerr=[df["err_lower"], df["err_upper"]],
    capsize=3,
    rot=90,
    ylabel=r"$\hat{V}(\pi)$",
    legend=False,
)
ax.axhline(y=df.iloc[0]["ground_truth"], color="r", linestyle="-")
ax.set_ylim(bottom=1.0)

ax.legend([r"$\hat{V} (\pi)$", r"$V(\pi)$"])

ax.figure.tight_layout()
ax.figure.savefig("OPE.png", bbox_inches="tight")

# %%
df_err = df[["bias2", "var", "mse"]]
ax = df_err.plot.bar()

ax.figure.get_axes()[0].legend([r"Bias$^2$", r"Var", r"MSE"])

ax.figure.tight_layout()
ax.figure.savefig("OPE-error_decomposition.png", bbox_inches="tight")

# %% [markdown]
# ### Sample size

# %%
rows = []

for sample_size in [100_000, 450_000, 900_000]:
    sample_size_bootstrap_results = Parallel(n_jobs=10)(
        delayed(estimator.benchmark)(
            name, T2_DATASET_PATH, result_ground_truth, sample_size
        )
        for (name, estimator) in estimators
    )

    for name, results, err in sample_size_bootstrap_results:
        rows.append(
            {
                "estimator": name,
                "sample_size": sample_size,
                "metric": results.metric,
                "lower_bound": results.ci.lower_bound,
                "upper_bound": results.ci.upper_bound,
                "err_lower": results.metric - results.ci.lower_bound,
                "err_upper": results.ci.upper_bound - results.metric,
                "ground_truth": result_ground_truth.metric,
                "bias2": err.bias2,
                "var": err.var,
                "mse": err.mse,
                "mse_lower_bound": err.ci.lower_bound,
                "mse_upper_bound": err.ci.upper_bound,
            }
        )

# %%
df = pd.DataFrame(rows)
df.to_csv("OPE-SampleSize.csv", index=False)

# %%
df

# %%
import itertools
import matplotlib.pyplot as plt
import numpy as np


# Display names
DISPLAY_NAMES = {
    "PBM-D": "PBM-D",
    "PBM-S": "PBM-S",
    "IPM": "IPM",
    "SN-IPM": "SN-IPM",
    "DM": "DM",
    "DR-IPM": "DR-IPM",
    "DR-IPM-S": "DR-IPM-S",
    "DR-PBM": "DR-PBM",
    "Interpol(window=1)": "Interpol(window=1)",
    "Interpol(window=2)": "Interpol(window=2)",
    "Interpol(window=3)": "Interpol(window=3)",
    "Interpol(window=4)": "Interpol(window=4)",
    "Interpol(window=5)": "Interpol(window=5)",
}

fig, ax = plt.subplots(figsize=(9.8, 3.5))

sample_sizes = sorted(df["sample_size"].unique())
x_positions = np.arange(len(sample_sizes))

# Get all unique estimators and assign colors
all_estimators = df["estimator"].unique()
colors = plt.cm.tab20(np.arange(len(all_estimators)))
markers = itertools.cycle(["o", "s", "^", "D", "v", "P", "*", "X"])
estimator_colors = dict(zip(all_estimators, colors))
estimator_markers = {est: next(markers) for est in all_estimators}

# For each sample size, sort estimators by error bar size
for idx, size in enumerate(sample_sizes):
    size_df = df[df["sample_size"] == size].copy()
    size_df["yerr"] = size_df["upper_bound"] - size_df["lower_bound"]
    size_df = size_df.sort_values("yerr", ascending=False)

    estimators = size_df["estimator"].values
    n_estimators = len(estimators)
    width = 0.8 / n_estimators

    for i, est in enumerate(estimators):
        row = size_df[size_df["estimator"] == est].iloc[0]
        x_offset = (i - n_estimators/2 + 0.5) * width
        x_pos = x_positions[idx] + x_offset
        y_val = row["metric"]
        y_err = [[y_val - row["lower_bound"]], [row["upper_bound"] - y_val]]

        label = DISPLAY_NAMES.get(est, est) if idx == 0 else ""
        ax.errorbar(x_pos, y_val, yerr=y_err, fmt="o", capsize=4, color=estimator_colors[est], label=label)

ax.axhline(df['ground_truth'].iloc[0], color="red", linestyle="--", label=r"$V(\pi)$")

ax.set_xticks(x_positions)
ax.set_xticklabels(sample_sizes)
ax.set_xlabel("Dataset size")
ax.set_ylabel(r"$\hat{V}(\pi)$")

handles, labels = ax.get_legend_handles_labels()
by_label = dict(zip(labels, handles))
ax.legend(by_label.values(), by_label.keys(), loc='lower right', ncol=4, fontsize='medium')

ax.figure.tight_layout()
ax.figure.savefig("SampleSize.png", bbox_inches="tight")
